# %% [markdown]
# ## Testing some python codes

# %% [markdown]
# # Load standard behavior and neural data

# %%
# cd to neuro-behavior/src directory, and add the figure_tools package folder to path
import os
os.chdir('E:/Projects/neuro-behavior/src/')
import sys
sys.path.append('E:/Projects/')
import figure_tools as ft
from neurobehavior.neuro_behavior_options import neuro_behavior_options
import matplotlib.pyplot as plt

# %%
# make any options changes
opts = neuro_behavior_options()
opts['frameSize'] = .2

# %run -i get_standard_data.py
# Out:
# in_nest_sleeping_or_irrelevant code -1.0 is not a valid behavior for this analysis
#
#
# Behavior 0.0: investigate_1
# 256: allPossible
# 246: andLongEnough
# 202: andNotRepeated
# Percent valid: 78.9
#
# Behavior 1.0: investigate_2
# 927: allPossible
# 878: andLongEnough
# 449: andNotRepeated
# Percent valid: 48.4
#
# Behavior 2.0: investigate_3
# 116: allPossible
# 110: andLongEnough
# 83: andNotRepeated
# Percent valid: 71.6
#
# Behavior 3.0: rear
# 32: allPossible
# 31: andLongEnough
# 26: andNotRepeated
# Percent valid: 81.2
#
# Behavior 4.0: dive_scrunch
# 114: allPossible
# 107: andLongEnough
# 97: andNotRepeated
# Percent valid: 85.1
#
# Behavior 5.0: paw_groom
# 100: allPossible
# 98: andLongEnough
# 66: andNotRepeated
# Percent valid: 66.0
#
# Behavior 6.0: face_groom_1
# 210: allPossible
# 200: andLongEnough
# 127: andNotRepeated
# Percent valid: 60.5
#
# Behavior 7.0: face_groom_2
# 135: allPossible
# 130: andLongEnough
# 74: andNotRepeated
# Percent valid: 54.8
#
# Behavior 8.0: head_groom
# 140: allPossible
# 134: andLongEnough
# 91: andNotRepeated
# Percent valid: 65.0
#
# Behavior 9.0: contra_body_groom
# 72: allPossible
# 68: andLongEnough
# 47: andNotRepeated
# Percent valid: 65.3
#
# Behavior 10.0: ipsi_body groom
# 112: allPossible
# 103: andLongEnough
# 67: andNotRepeated
# Percent valid: 59.8
#
# Behavior 11.0: contra_itch
# 171: allPossible
# 157: andLongEnough
# 113: andNotRepeated
# Percent valid: 66.1
#
# Behavior 12.0: ipsi_itch_1
# 135: allPossible
# 123: andLongEnough
# 85: andNotRepeated
# Percent valid: 63.0
#
# Behavior 13.0: contra_orient
# 349: allPossible
# 304: andLongEnough
# 248: andNotRepeated
# Percent valid: 71.1
#
# Behavior 14.0: ipsi_orient
# 492: allPossible
# 431: andLongEnough
# 332: andNotRepeated
# Percent valid: 67.5
#
# Behavior 15.0: locomotion
# 1003: allPossible
# 965: andLongEnough
# 500: andNotRepeated
# Percent valid: 49.9
#
#
# Keeping 225 of 499 neurons
# 20 M23
# 49 M56
# 96 DS
# 60 VS

# %% [markdown]
# # Pacmap

# %%
idInd = idDS

# %%
# %matplotlib notebook
import pacmap
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

bhvColors = ft.colors_for_behaviors(behaviors)
# Prepare colors: Map each label to its RGB color
colors = np.array([bhvColors[label] for label in bhvIDMat])  # Adjust indexing if necessary

X = dataMat[:, idDS]
# X = X.reshape(X.shape[0], -1)
y = bhvIDMat

# initializing the pacmap instance
# Setting n_neighbors to "None" leads to a default choice shown below in "parameter" section
embedding = pacmap.PaCMAP(n_components=2, n_neighbors=None, MN_ratio=0.5, FP_ratio=2.0) 

# fit the data (The index of transformed data corresponds to the index of the original data)
X_transformed = embedding.fit_transform(X, init="pca")

# The third dimension (Z) is a sequence from 1 to dataMat.shape[0]
z = np.arange(1, dataMat.shape[0] + 1)

# visualize the embedding
fig = plt.figure(figsize=(14,14))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(X_transformed[:, 0], X_transformed[:, 1], z, color=colors, s=5, 
           marker='o', linewidths=1.5, facecolors='none')
ax.set_title('PACMAP projection of the dataMat dataset', fontsize=24)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
plt.show()

# %% [markdown]
# ## UMAP

# %%
behaviors
# Out:
# ['in_nest_sleeping_or_irrelevant',
#  'investigate_1',
#  'investigate_2',
#  'investigate_3',
#  'rear',
#  'dive_scrunch',
#  'paw_groom',
#  'face_groom_1',
#  'face_groom_2',
#  'head_groom',
#  'contra_body_groom',
#  'ipsi_body groom',
#  'contra_itch',
#  'ipsi_itch_1',
#  'contra_orient',
#  'ipsi_orient',
#  'locomotion']

# %%
import numpy as np
import umap
import matplotlib.pyplot as plt

bhvColors = ft.colors_for_behaviors(behaviors)

# Initialize UMAP. You can adjust the parameters as needed.
reducer = umap.UMAP(n_neighbors=15, n_components=2, metric='euclidean')

# Fit the model to your data
embedding = reducer.fit_transform(dataMat[:, idInd])

# Prepare colors: Map each label to its RGB color
colors = np.array([bhvColors[label] for label in bhvIDMat])  # Adjust indexing if necessary

# Plotting the result
plt.figure(figsize=(12, 10))
plt.scatter(embedding[:, 0], embedding[:, 1], color=colors, s=5)
plt.title('UMAP projection of the dataMat dataset', fontsize=24)
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.show()
